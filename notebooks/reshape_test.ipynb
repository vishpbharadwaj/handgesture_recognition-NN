# %%
# %% Import tensorflow and pyplot
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import math

# %%
# %% First a tf.Tensor
n_values = 32

# %%
def makeGaussian(size, fwhm = 15, center=None):
    """ Make a square gaussian kernel.

    size is the length of a side of the square
    fwhm is full-width-half-maximum, which
    can be thought of as an effective radius.
    """

    x = np.arange(0, size, 1)
    y = x[:,np.newaxis]

    if center is None:
        x0 = y0 = size // 2
    else:
        x0 = center[0]
        y0 = center[1]

    return np.exp(-4*np.log(2) * ((x-x0)**2 + (y-y0)**2) / fwhm**2)

z = makeGaussian(n_values)

# %%
print(z.shape)
plt.imshow(z)
plt.show()
# Out:
# (32, 32)

# %%
a = np.array([z,z])
a.shape
b = np.array([a,a])
print(b.shape)
b
# Out:
# (2, 2, 32, 32)
# array([[[[ 0.00181953,  0.00266599,  0.00381116, ...,  0.00531559,
#            0.00381116,  0.00266599],
#          [ 0.00266599,  0.00390625,  0.00558416, ...,  0.00778847,
#            0.00558416,  0.00390625],
#          [ 0.00381116,  0.00558416,  0.0079828 , ...,  0.01113396,
#            0.0079828 ,  0.00558416],
#          ...,
#          [ 0.00531559,  0.00778847,  0.01113396, ...,  0.01552903,
#            0.01113396,  0.00778847],
#          [ 0.00381116,  0.00558416,  0.0079828 , ...,  0.01113396,
#            0.0079828 ,  0.00558416],
#          [ 0.00266599,  0.00390625,  0.00558416, ...,  0.00778847,
#            0.00558416,  0.00390625]],
#
#         [[ 0.00181953,  0.00266599,  0.00381116, ...,  0.00531559,
#            0.00381116,  0.00266599],
#          [ 0.00266599,  0.00390625,  0.00558416, ...,  0.00778847,
#            0.00558416,  0.00390625],
#          [ 0.00381116,  0.00558416,  0.0079828 , ...,  0.01113396,
#            0.0079828 ,  0.00558416],
#          ...,
#          [ 0.00531559,  0.00778847,  0.01113396, ...,  0.01552903,
#            0.01113396,  0.00778847],
#          [ 0.00381116,  0.00558416,  0.0079828 , ...,  0.01113396,
#            0.0079828 ,  0.00558416],
#          [ 0.00266599,  0.00390625,  0.00558416, ...,  0.00778847,
#            0.00558416,  0.00390625]]],
#
#
#        [[[ 0.00181953,  0.00266599,  0.00381116, ...,  0.00531559,
#            0.00381116,  0.00266599],
#          [ 0.00266599,  0.00390625,  0.00558416, ...,  0.00778847,
#            0.00558416,  0.00390625],
#          [ 0.00381116,  0.00558416,  0.0079828 , ...,  0.01113396,
#            0.0079828 ,  0.00558416],
#          ...,
#          [ 0.00531559,  0.00778847,  0.01113396, ...,  0.01552903,
#            0.01113396,  0.00778847],
#          [ 0.00381116,  0.00558416,  0.0079828 , ...,  0.01113396,
#            0.0079828 ,  0.00558416],
#          [ 0.00266599,  0.00390625,  0.00558416, ...,  0.00778847,
#            0.00558416,  0.00390625]],
#
#         [[ 0.00181953,  0.00266599,  0.00381116, ...,  0.00531559,
#            0.00381116,  0.00266599],
#          [ 0.00266599,  0.00390625,  0.00558416, ...,  0.00778847,
#            0.00558416,  0.00390625],
#          [ 0.00381116,  0.00558416,  0.0079828 , ...,  0.01113396,
#            0.0079828 ,  0.00558416],
#          ...,
#          [ 0.00531559,  0.00778847,  0.01113396, ...,  0.01552903,
#            0.01113396,  0.00778847],
#          [ 0.00381116,  0.00558416,  0.0079828 , ...,  0.01113396,
#            0.0079828 ,  0.00558416],
#          [ 0.00266599,  0.00390625,  0.00558416, ...,  0.00778847,
#            0.00558416,  0.00390625]]]])

# %%
c = b.reshape([n_values*2,2*n_values])
print(c.shape)
# Out:
# (64, 64)

# %%
plt.imshow(c)
plt.show()
